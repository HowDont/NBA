# %%
from nba_api.stats.endpoints import playercareerstats
career = playercareerstats.PlayerCareerStats(player_id='201142')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201142   2007-08        00  1610612760               SEA        19.0
# 1      201142   2008-09        00  1610612760               OKC        20.0
# 2      201142   2009-10        00  1610612760               OKC        21.0
# 3      201142   2010-11        00  1610612760               OKC        22.0
# 4      201142   2011-12        00  1610612760               OKC        23.0
# 5      201142   2012-13        00  1610612760               OKC        24.0
# 6      201142   2013-14        00  1610612760               OKC        25.0
# 7      201142   2014-15        00  1610612760               OKC        26.0
# 8      201142   2015-16        00  1610612760               OKC        27.0
# 9      201142   2016-17        00  1610612744               GSW        28.0
# 10     201142   2017-18        00  1610612744               GSW        29.0
# ...

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2
boxScore = boxscoreadvancedv2.BoxScoreAdvancedv2(player_id='201142')
boxScore.get_data_frames()[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-899e8437e83e> in <module>
#       1 from nba_api.stats.endpoints import boxscoreadvancedv2
# ----> 2 boxScore = boxscoreadvancedv2.BoxScoreAdvancedv2(player_id='201142')
#       3 boxScore.get_data_frames()[0]
#
# AttributeError: module 'nba_api.stats.endpoints.boxscoreadvancedv2' has no attribute 'BoxScoreAdvancedv2'

# %%
## short chard details
from nba_api.stats.endpoints import ShotChartDetail

# %%
player_id = '201566' # fill in the player you care about
shot_char_detail_dfs = ShotChartDetail(team_id='1610612745', player_id=player_id, season_nullable='2019-20', context_measure_simple='FGA').get_data_frames()[0]

# %%
shot_char_detail_dfs
# Out:
#               GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0     Shot Chart Detail  0021900015             49     201566
# 1     Shot Chart Detail  0021900015            155     201566
# 2     Shot Chart Detail  0021900015            169     201566
# 3     Shot Chart Detail  0021900015            220     201566
# 4     Shot Chart Detail  0021900015            249     201566
# ...                 ...         ...            ...        ...
# 1276  Shot Chart Detail  0021901298            373     201566
# 1277  Shot Chart Detail  0021901298            391     201566
# 1278  Shot Chart Detail  0021901298            401     201566
# 1279  Shot Chart Detail  0021901298            410     201566
# 1280  Shot Chart Detail  0021901298            448     201566
#
#             PLAYER_NAME     TEAM_ID        TEAM_NAME  PERIOD  \
# 0     Russell Westbrook  1610612745  Houston Rockets       1
# 1     Russell Westbrook  1610612745  Houston Rockets       1
# ...

# %%
shot_char_detail_dfs.SHOT_DISTANCE.unique()
# Out:
# array([26, 17,  2,  3, 19, 24,  0, 25, 14,  5, 23, 20, 16,  1, 13,  7, 10,
#        12,  8, 11, 18, 15, 22, 44, 21,  9,  6,  4, 27, 29, 28, 36],
#       dtype=int64)

# %%
shot_char_detail_dfs.loc[shot_char_detail_dfs['SHOT_DISTANCE']>26].shape[0]
# Out:
# 21

# %%
shot_char_detail_dfs.loc[shot_char_detail_dfs['SHOT_DISTANCE']>26]['SHOT_DISTANCE'].mean()
# Out:
# 28.61904761904762

# %%
shot_char_detail_dfs.loc[(shot_char_detail_dfs['SHOT_DISTANCE']>26)&(shot_char_detail_dfs['SHOT_MADE_FLAG']==1)].shape[0]
# Out:
# 2

# %%
sns.scatterplot(x='LOC_X', y='LOC_Y', data=shot_char_detail_dfs, color='lightblue')

# %%
sns.scatterplot(x='LOC_X', y='LOC_Y', data=shot_char_detail_dfs.loc[shot_char_detail_dfs['SHOT_DISTANCE']>24], color='lightblue')

# %%
sns.scatterplot(x='LOC_X', y='LOC_Y', data=shot_char_detail_dfs.loc[shot_char_detail_dfs['SHOT_DISTANCE']>26], color='lightblue')

# %%
shot_char_detail_dfs.loc[shot_char_detail_dfs['SHOT_DISTANCE']>26].to_csv (r'C:\Users\mikes\Desktop\export_dataframe.csv', index = False, header=True)

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Function to draw basketball court
def create_court(ax, color):
    # Short corner 3PT lines
    ax.plot([-220, -220], [0, 140], linewidth=2, color=color)
    ax.plot([220, 220], [0, 140], linewidth=2, color=color)
# 3PT Arc
    ax.add_artist(mpl.patches.Arc((0, 140), 440, 315, theta1=0, theta2=180, facecolor='none', edgecolor=color, lw=2))
# Lane and Key
    ax.plot([-80, -80], [0, 190], linewidth=2, color=color)
    ax.plot([80, 80], [0, 190], linewidth=2, color=color)
    ax.plot([-60, -60], [0, 190], linewidth=2, color=color)
    ax.plot([60, 60], [0, 190], linewidth=2, color=color)
    ax.plot([-80, 80], [190, 190], linewidth=2, color=color)
    ax.add_artist(mpl.patches.Circle((0, 190), 60, facecolor='none', edgecolor=color, lw=2))
# Rim
    ax.add_artist(mpl.patches.Circle((0, 60), 15, facecolor='none', edgecolor=color, lw=2))
    
# Backboard
    ax.plot([-30, 30], [40, 40], linewidth=2, color=color)

# Remove ticks
    ax.set_xticks([])
    ax.set_yticks([])
    
# Set axis limits
    ax.set_xlim(-250, 250)
    ax.set_ylim(0, 470)

# %%
mpl.rcParams['font.family'] = 'Avenir'
mpl.rcParams['font.size'] = 18
mpl.rcParams['axes.linewidth'] = 2

# %%
fig = plt.figure(figsize=(4, 3.76))
ax = fig.add_axes([0, 0, 1, 1])
ax = create_court(ax, 'black')
plt.show()

# %%
#https://towardsdatascience.com/make-a-simple-nba-shot-chart-with-python-e5d70db45d0d

# %%
import seaborn as sns

# %%
#https://medium.com/@fastbreakstatistics/creating-the-nba-shotchart-using-python-5c595374d905

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.patches import Circle, Rectangle, Arc, ConnectionPatch

# %%
sns.scatterplot(x='LOC_X', y='LOC_Y', data=shot_char_detail_dfs, color='lightblue')
